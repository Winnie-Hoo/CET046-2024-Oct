# %% [markdown]
# <a href="https://colab.research.google.com/github/Winnie-Hoo/CET046-2024-Oct/blob/main/Bankruptcy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/bankruptcy.csv")

# %%
df
# Out:
#          Attr1     Attr2     Attr3     Attr4     Attr5     Attr6     Attr7  \
# 0    -0.031545 -0.091313 -0.040269 -0.013529  0.007406 -0.016047 -0.000264
# 1    -0.231729 -0.049448  0.304381 -0.080975  0.007515 -0.016047 -0.034963
# 2    -0.058602  0.065060 -0.488404 -0.189489  0.006572 -0.016047 -0.004954
# 3    -0.069376  0.044641 -0.181684 -0.140032  0.007477 -0.010915 -0.005599
# 4     0.236424 -0.051912  0.678337 -0.014680  0.007879 -0.016047  0.057418
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995 -0.079533  0.034814 -0.492082 -0.189873  0.006687 -0.006462 -0.008582
# 9996 -0.081046 -0.095260  0.184167  0.021280  0.007497 -0.034968 -0.009689
# 9997 -0.230571  0.061341 -0.830634 -0.222373  0.006716 -0.013742 -0.042210
# 9998 -0.108156  0.029524  0.102420 -0.042692  0.008123 -0.018374 -0.013544
# 9999 -0.068674 -0.081793  0.734155  0.039538  0.007850  0.001952 -0.005791
#
# ...

# %%
Y = df['class']
X = df.drop('class', axis =1)

# %%
df.isna().sum()
# Out:
# Attr1     0
# Attr2     0
# Attr3     0
# Attr4     0
# Attr5     0
#          ..
# Attr61    0
# Attr62    0
# Attr63    0
# Attr64    0
# class     0
# Length: 65, dtype: int64

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'Attr1'}>,
#         <Axes: title={'center': 'Attr2'}>,
#         <Axes: title={'center': 'Attr3'}>,
#         <Axes: title={'center': 'Attr4'}>,
#         <Axes: title={'center': 'Attr5'}>,
#         <Axes: title={'center': 'Attr6'}>,
#         <Axes: title={'center': 'Attr7'}>,
#         <Axes: title={'center': 'Attr8'}>],
#        [<Axes: title={'center': 'Attr9'}>,
#         <Axes: title={'center': 'Attr10'}>,
#         <Axes: title={'center': 'Attr11'}>,
#         <Axes: title={'center': 'Attr12'}>,
#         <Axes: title={'center': 'Attr13'}>,
#         <Axes: title={'center': 'Attr14'}>,
#         <Axes: title={'center': 'Attr15'}>,
#         <Axes: title={'center': 'Attr16'}>],
#        [<Axes: title={'center': 'Attr17'}>,
#         <Axes: title={'center': 'Attr18'}>,
#         <Axes: title={'center': 'Attr19'}>,
#         <Axes: title={'center': 'Attr20'}>,
#         <Axes: title={'center': 'Attr21'}>,
# ...

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.boxplot(x='Attr1', data=df)
# Out:
# <Axes: xlabel='Attr1'>

# %%
sns.countplot(x="class", data=df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.catplot(x='class', y="Attr1", data=df, kind='violin')

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn import tree

# %%
from sklearn.metrics import accuracy_score,confusion_matrix, classification_report

# %%
model = tree.DecisionTreeClassifier(random_state=42)

# %%
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
pred = model.predict(x_test)

# %%
cm = confusion_matrix(y_test, pred)

# %%
cm
# Out:
# array([[1927,   35],
#        [  24,   14]])

# %%
accuracy_score(y_test, pred)
# Out:
# 0.9705

# %%
classification_report(y_test, pred)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.99      0.98      0.98      1962\n           1       0.29      0.37      0.32        38\n\n    accuracy                           0.97      2000\n   macro avg       0.64      0.68      0.65      2000\nweighted avg       0.97      0.97      0.97      2000\n'

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(random_state=42)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
pred = model.predict(x_test)

# %%
accuracy_score(y_test, pred)
# Out:
# 0.9805

# %%
cm = confusion_matrix(y_test, pred)

# %%
cm
# Out:
# array([[1960,    2],
#        [  37,    1]])
